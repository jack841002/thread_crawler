# %%
import requests
import numpy as np  
from bs4 import BeautifulSoup
import re #抓圖片
from urllib.request import urlretrieve #存照片
import os #為了建立資料夾
import sys #控制抓取文章頁數 system的縮寫
import threading
import time

with open('thread_train_img.txt','r') as fp:
    img = fp.read().splitlines()

errf = open("thread_example.txt", "a")

error=[] #len(img) 16078
outNum = 0 # sync

# num = 10

def func(url):
    global outNum
    lock.acquire()
    time.sleep(0.01)
    #num = num - 1
    
    try:
        res = requests.get(url)
        soup = BeautifulSoup(res.text,"html.parser")
        if soup.find('div').find('img') != None:
            image = soup.find('div').find('img')['src']
            f = image.split('/')[-1]
            f = f.split('_')[0]
            local = os.path.abspath('./image/{}.jpg'.format(f))
            try:
                urlretrieve(image,local) #image是下載的網址 local是儲存圖片的檔案位址
                outNum = outNum +1
                print("process {} urls ".format(outNum))
            except Exception as e:
                print(url)
                errf.writelines(str(url) + "\n")                
                error.append(url)
                print(e)
        else:
            print(url)
            errf.writelines(str(url) + "\n")
            error.append(url)
    except Exception as e:
        print(url)
        errf.writelines(str(url) + "\n")
        error.append(url)
    
    lock.release()
    #print(num)

threads = []

lock = threading.BoundedSemaphore(10) #最多允許5個執行緒同時執行
for i in range(0,300):
#     print("process {} urls ".format(i+1))
    # errf.writelines(str(i)+'\n')
    url = img[i]    
    t = threading.Thread(target=func,args=(url,))
    threads.append(t)
    t.start()

for t in threads:
    t.join()

print("主執行緒：", threading.current_thread().name)
# Out:
# process 1 urls
# process 2 urls
# process 3 urls
# process 4 urls
# process 5 urls
# process 6 urls
# process 7 urls
# process 8 urls process 9 urls
#
# process 10 urls
# process 11 urls
# process 12 urls
# process 13 urls
# process 14 urls
# process 15 urls
# process 16 urls
# process 17 urls
# process 18 urls
# process 19 urls
# process 20 urls
# process 21 urls
# process 22 urls
# process 23 urls
# https://www.flickr.com/photos/44858354@N04/4539637503
# process 24 urls
# process 25 urls
# process 26 urls
# process 27 urls
# process 28 urls
# process 29 urls
# https://www.flickr.com/photos/44858354@N04/4539669757
# https://www.flickr.com/photos/44858354@N04/4539669535
# https://www.flickr.com/photos/44858354@N04/4540271148
# process 30 urls
# https://www.flickr.com/photos/44858354@N04/4540271060
# https://www.flickr.com/photos/44858354@N04/4540271514
# process 31 urls
# process 32 urls
# process 33 urls
# process 34 urls
# process 35 urls
# process 36 urls
# process 37 urls
# process 38 urls
# process 39 urls
# process 40 urls process 41 urls
#
# process 42 urls
# process 43 urls
# process 44 urls
# process 45 urls
# process 46 urls
# process 47 urls
# process 48 urls
# process 49 urls
# process 50 urls
# process 51 urls
# process 52 urls
# process 53 urls
# process 54 urls
# process 55 urls
# process 56 urls
# process 57 urls
# process 58 urls
# https://www.flickr.com/photos/44858354@N04/5277019485
# process 59 urls
# process 60 urls
# process 61 urls
# process 62 urls
# process 63 urls
# process 64 urls
# process 65 urls
# process 66 urls
# process 67 urls
# process 68 urls
# https://www.flickr.com/photos/44858354@N04/5355068084
# https://www.flickr.com/photos/44858354@N04/5364336029
# https://www.flickr.com/photos/44858354@N04/5360808046
# https://www.flickr.com/photos/44858354@N04/5365288747
# process 69 urls
# process 70 urls
# process 71 urls
# process 72 urls
# https://www.flickr.com/photos/44858354@N04/5371023056
# process 73 urls
# https://www.flickr.com/photos/44858354@N04/5414663544
# process 74 urls process 75 urls
#
# process 76 urls
# https://www.flickr.com/photos/44858354@N04/5475291309
# https://www.flickr.com/photos/44858354@N04/5461446930
# process 77 urls
# process 78 urls
# process 79 urls
# process 80 urls
# https://www.flickr.com/photos/44858354@N04/5475165155
# process 81 urls
# process 82 urls
# process 83 urls
# https://www.flickr.com/photos/44858354@N04/5477513484
# process 84 urls
# https://www.flickr.com/photos/44858354@N04/5476944577
# process 85 urls
# https://www.flickr.com/photos/44858354@N04/5477542998
# https://www.flickr.com/photos/44858354@N04/5477542964
# https://www.flickr.com/photos/44858354@N04/5476944787
# process 86 urls
# https://www.flickr.com/photos/44858354@N04/5477543134
# process 87 urls
# process 88 urls
# https://www.flickr.com/photos/44858354@N04/5477543758
# process 89 urls
# process 90 urls
# process 91 urls
# process 92 urls
# process 93 urls
# https://www.flickr.com/photos/55066757@N02/5595498379
# process 94 urls
# process 95 urls
# process 96 urls
# https://www.flickr.com/photos/97042891@N00/5947241025
# process 97 urls
# process 98 urls
# https://www.flickr.com/photos/44858354@N04/5713014431
# process 99 urls
# process 100 urls
# process 101 urls
# process 102 urls
# process 103 urls process 104 urls
#
# process 105 urls
# process 106 urls
# process 107 urls
# process 108 urls
# process 109 urls
# process 110 urls
# process 111 urls
# process 112 urls
# process 113 urls
# https://www.flickr.com/photos/97042891@N00/6912542267
# process 114 urls
# process 115 urls
# process 116 urls
# https://www.flickr.com/photos/46484616@N04/6446610641
# process 117 urls
# process 118 urls
# https://www.flickr.com/photos/77885581@N08/7003247450
# process 119 urls
# https://www.flickr.com/photos/77885581@N08/7612707302
# https://www.flickr.com/photos/77885581@N08/7355997324
# process 120 urls
# process 121 urls
# process 122 urls
# process 123 urls
# process 124 urls
# process 125 urls
# process 126 urls
# process 127 urls
# process 128 urls
# process 129 urls
# process 130 urls
# process 131 urls
# process 132 urls
# process 133 urls
# process 134 urls
# process 135 urls
# process 136 urls
# process 137 urls
# process 138 urls
# process 139 urls
# process 140 urls
# https://www.flickr.com/photos/77885581@N08/8144319841
# https://www.flickr.com/photos/76648979@N06/8221722334
# https://www.flickr.com/photos/90250231@N05/8207735779
# process 141 urls
# process 142 urls
# process 143 urls
# process 144 urls
# https://www.flickr.com/photos/77885581@N08/8285643658
# https://www.flickr.com/photos/77885581@N08/8146078203
# https://www.flickr.com/photos/77885581@N08/8270186769
# process 145 urls
# process 146 urls
# process 147 urls
# process 148 urls
# process 149 urls
# process 150 urls
# process 151 urls
# process 152 urls
# process 153 urls
# process 154 urls
# process 155 urls
# process 156 urls
# process 157 urls process 158 urls
#
# process 159 urls
# process 160 urls
# process 161 urls
# process 162 urls
# process 163 urls
# process 164 urls
# process 165 urls
# process 166 urls
# process 167 urls
# process 168 urls
# process 169 urls
# process 170 urls
# process 171 urls
# process 172 urls
# process 173 urls
# process 174 urls
# https://www.flickr.com/photos/44858354@N04/10355489736
# process 175 urls
# process 176 urls
# process 177 urls
# process 178 urls
# https://www.flickr.com/photos/44858354@N04/10355607334
# process 179 urls
# process 180 urls
# process 181 urls
# process 182 urls
# process 183 urls
# process 184 urls
# https://www.flickr.com/photos/44858354@N04/10614070944
# process 185 urls
# process 186 urls
# process 187 urls
# https://www.flickr.com/photos/44858354@N04/11302226484
# process 188 urls
# process 189 urls
# process 190 urls
# process 191 urls
# https://www.flickr.com/photos/44858354@N04/11305193034
# process 192 urls
# process 193 urls
# process 194 urls
# process 195 urls
# process 196 urls
# process 197 urls
# process 198 urls
# process 199 urls
# process 200 urls
# process 201 urls
# process 202 urls
# https://www.flickr.com/photos/9814014@N04/11596646246
# process 203 urls
# process 204 urls
# process 205 urls
# process 206 urls
# process 207 urls
# process 208 urls
# process 209 urls
# https://www.flickr.com/photos/116161185@N07/12673490904
# https://www.flickr.com/photos/77885581@N08/12520665663
# process 210 urls
# process 211 urls
# process 212 urls
# process 213 urls
# process 214 urls
# process 215 urls
# process 216 urls
# process 217 urls
# process 218 urls
# process 219 urls
# https://www.flickr.com/photos/44858354@N04/14337779280
# process 220 urls
# process 221 urls
# https://www.flickr.com/photos/77885581@N08/14014740720
# process 222 urls
# https://www.flickr.com/photos/44858354@N04/14501084566
# process 223 urls
# process 224 urls
# process 225 urls
# https://www.flickr.com/photos/44858354@N04/14602688729
# process 226 urls
# process 227 urls
# process 228 urls
# https://www.flickr.com/photos/44858354@N04/14631880306
# https://www.flickr.com/photos/44858354@N04/14661701237
# https://www.flickr.com/photos/44858354@N04/14657703306
# https://www.flickr.com/photos/44858354@N04/14678324951
# process 229 urls
# https://www.flickr.com/photos/44858354@N04/14677694391
# https://www.flickr.com/photos/44858354@N04/14705272669
# process 230 urls
# process 231 urls
# process 232 urls
# process 233 urls
# process 234 urls
# process 235 urls
# process 236 urls
# process 237 urls
# https://www.flickr.com/photos/44858354@N04/14849377586
# https://www.flickr.com/photos/44858354@N04/14786680186
# https://www.flickr.com/photos/44858354@N04/14888046579
# https://www.flickr.com/photos/44858354@N04/14892278243
# https://www.flickr.com/photos/44858354@N04/14890268741
# process 238 urls
# https://www.flickr.com/photos/44858354@N04/14893336715
# process 239 urls
# 主執行緒： MainThread
